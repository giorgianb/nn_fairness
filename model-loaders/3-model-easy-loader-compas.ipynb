# %%
import pandas as pd 
import numpy as np 
from os.path import join as os_join
import json
import os
import pprint
import matplotlib.pyplot as plt
import pickle
pp = pprint.PrettyPrinter(width=41, compact=True)
# white, professional/manager, US vs non-US, workclass (gov vs private)

# %% [markdown]
# # 0. Model input:
# ```
# x = [np_age, np_prior, np_race, np_sex]
# y = [ np_score, np_truth ]
#
# np_score: The danger score from judgement system
# np_truth: If this person commit crime in next two years
# ```
#
# The models are trained to fit ```np_score```.
#
# The features:
# ```
# age             :       normalized to [0,1]
# np_prior         :       normalized to [0,1]
# np_race  :       1 means African-American, 0 means Caucasian
# np_sex         : 1.0 means male, 0.0 means female,
#
# ```

# %% [markdown]
# # 1. Data distribution

# %%
    
cache_path = 'NN-verification/cache'
random_seed = 0
cache_file_path = os_join(cache_path,f'np-compas-data-rs={random_seed}.pkl')
with open(cache_file_path, 'rb') as f:
    data_dict = pickle.load(f)
X_train = data_dict["X_train"]
y_train = data_dict["y_train"]
X_dev = data_dict["X_dev"]
y_dev = data_dict["y_dev"]
X_test = data_dict["X_test"]
y_test = data_dict["y_test"]
input_shape = X_train.shape[1]
print('X_train set:', X_train.shape)
print('X_dev set:', X_dev.shape)
print('X_test set:', X_test.shape)


# testing data distribution:
age_feat = (X_test[:,0],'age ')
prior_feat = (X_test[:,1],'prior (min:16, max: 1)')
race_feat = (X_test[:,2],'1: black, 0: white')
sex_feat = (X_test[:,3],'sex (1:male, 0:female)')


plot_data = [age_feat, prior_feat, race_feat, sex_feat]
fig, axs = plt.subplots(1,4, figsize =(20,4))
axs = axs.flatten()
for (_d, _text), ax in zip(plot_data, axs):
    ax.hist(_d)
    ax.set_title(_text)
    
# ax = axs[4]
# axis_text = ['White', 'Black', 'Asian-Pac-Islander','Amer-Indian-Eskimo', 'Other']
# ax.barh(axis_text, race_feat[0])
# ax.set_title(race_feat[1])
# ax.tick_params(axis='y', labelrotation = 45)
# fig.tight_layout()
# Out:
# X_train set: (2363, 4)
# X_dev set: (507, 4)
# X_test set: (507, 4)

# %% [markdown]
# # 2. Load Model
# ### 1. Change res_root_path to the correct path, Something like:
# ```
# res_root_path = '/Users/xingzhiguo/Documents/git_project/NN-verification/results'
# ```

# %%
res_root_path = 'NN-verification/results'

# %%
def tell_me_model(random_seed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config):
    res_root_path = 'NN-verification/results'
    max_epoch = 10
    train_bs = 32
    # eval_bs = 128
    # lr = 0.01
    model_save_dir = os_join(res_root_path, f'compas-model_config-{model_config}-max_epoch={max_epoch}-train_bs={train_bs}-random_seed={random_seed}-is_random_weight-{is_random_weight}-race_permute={is_race_permute}-sex_permute={is_sex_permute}-both_sex_race_permute={is_sex_race_both_permute}')
    onnx_file_path = os_join(model_save_dir, 'model.onnx')
    training_stats_file = os_join(model_save_dir, 'res-stats.json')
    # print (f'onnx is here: {onnx_file_path}' )
    # print (f'train-stats is here: {training_stats_file}' )
    
    with open(training_stats_file, 'r') as f:
        line = f.readline()
        train_stats = json.loads(line)
        # pp.pprint(train_stats)
    return [onnx_file_path], [train_stats]

def tell_me_model_aug_fair_train(random_seed, is_race_permute, is_sex_permute, is_sex_race_both_permute, 
                is_random_weight, 
                is_fair_train_remove_sym_diff,
                is_fair_train_flip_duplicate_sym_diff,
                is_fair_train_iter_flip_duplicate_sym_diff,
                model_config):
    res_root_path = 'NN-verification/results'
    max_epoch = 10
    train_bs = 32
    # eval_bs = 128
    # lr = 0.01
    model_save_dir = os_join(res_root_path, f'compas-model_config-{model_config}-max_epoch={max_epoch}-train_bs={train_bs}-random_seed={random_seed}-is_random_weight-{is_random_weight}-race_permute={is_race_permute}-sex_permute={is_sex_permute}'+
                                    f'-both_sex_race_permute={is_sex_race_both_permute}-is_fair_rmv_sym_diff={is_fair_train_remove_sym_diff}-is_fair_copy_sym_diff={is_fair_train_flip_duplicate_sym_diff}-is_fair_iter_copy_sym_diff={is_fair_train_iter_flip_duplicate_sym_diff}')
    #onnx_file_path = os_join(model_save_dir, 'model.onnx')
    #training_stats_file = os_join(model_save_dir, 'res-stats.json')
    #print (f'onnx is here: {onnx_file_path}' )
    #print (f'train-stats is here: {training_stats_file}' )
    
    # with open(training_stats_file, 'r') as f:
    #     line = f.readline()
    #     train_stats = json.loads(line)
    #     pp.pprint(train_stats)
    training_stats_files = []
    
    onnx_file_path_list, train_stats_list = [], []
    for K in range(10):
        _ = os_join(model_save_dir, f'res-stats-iter-{K}.json')
        onnx_file = os_join(model_save_dir, f'model-iter-{K}.onnx')
        if os.path.exists(_) is not True:
            break 
        else:
            training_stats_files.append(_)
            onnx_file_path_list.append(onnx_file)
    # print (len(training_stats_files))
    
    for _ in training_stats_files:
        with open(_,'r') as f :
            data = json.loads(f.readline())
            train_stats_list.append(data)
    #print(train_data)
    return onnx_file_path_list, train_stats_list

# %% [markdown]
# # Fetch the trained models with performance (auc) during train/val/test

# %%
model_summary = []

model_configs = ['small','medium']
num_random_seed = 5 # only repeat for once 
for model_config in model_configs:
    # normal model
    is_race_permute = False 
    is_sex_permute =  False
    is_sex_race_both_permute = False
    is_random_weight = False
    for randseed in range(num_random_seed): 
        onnx_file_path_list, train_stats_list = tell_me_model(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config)
        res_dict = {'strategy': 'original', 
                    'random_seed': randseed,
                    'model_size': model_config, 
                    'onnx_list':  onnx_file_path_list,
                    'model_stats':  train_stats_list,
                    }
        model_summary.append(res_dict)
        

    # race-permute only model
    is_race_permute = True 
    is_sex_permute =  False
    is_sex_race_both_permute = False
    is_random_weight = False
    for randseed in range(num_random_seed): 
        onnx_file_path_list, train_stats_list = tell_me_model(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config)
        res_dict = {'strategy': 'race-permute', 
                    'random_seed': randseed,
                    'model_size': model_config, 
                    'onnx_list':  onnx_file_path_list,
                    'model_stats':  train_stats_list,
                    }
        model_summary.append(res_dict)

    # remove sym diff instance
    is_race_permute = False 
    is_sex_permute =  False
    is_sex_race_both_permute = False
    is_random_weight = False
    is_fair_train_remove_sym_diff = True
    is_fair_train_flip_duplicate_sym_diff = False
    is_fair_train_iter_flip_duplicate_sym_diff = False
    for randseed in range(num_random_seed): 
        onnx_file_path_list, train_stats_list = tell_me_model_aug_fair_train(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, 
                is_random_weight, 
                is_fair_train_remove_sym_diff,
                is_fair_train_flip_duplicate_sym_diff,
                is_fair_train_iter_flip_duplicate_sym_diff,
                model_config)
        res_dict = {'strategy': 'Rmv-SymDiff', 
                    'random_seed': randseed,
                    'model_size': model_config, 
                    'onnx_list':  onnx_file_path_list,
                    'model_stats':  train_stats_list,
                    }
        model_summary.append(res_dict)

    # augment sym diff instance
    is_race_permute = False 
    is_sex_permute =  False
    is_sex_race_both_permute = False
    is_random_weight = False
    is_fair_train_remove_sym_diff = False
    is_fair_train_flip_duplicate_sym_diff = True
    is_fair_train_iter_flip_duplicate_sym_diff = False
    for randseed in range(num_random_seed): 
        onnx_file_path_list, train_stats_list = tell_me_model_aug_fair_train(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, 
                is_random_weight, 
                is_fair_train_remove_sym_diff,
                is_fair_train_flip_duplicate_sym_diff,
                is_fair_train_iter_flip_duplicate_sym_diff,
                model_config)
        res_dict = {'strategy': 'Aug-SymDiff', 
                    'random_seed': randseed,
                    'model_size': model_config, 
                    'onnx_list':  onnx_file_path_list,
                    'model_stats':  train_stats_list,
                    }
        model_summary.append(res_dict)



    # random model
    # is_race_permute = False 
    # is_sex_permute =  False
    # is_sex_race_both_permute = False
    # is_random_weight = True
    # for randseed in range(num_random_seed):
    #     onnx_file_path_list, train_stats_list = tell_me_model(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config)

    # sex-permute only model
    # is_race_permute = False 
    # is_sex_permute =  True
    # is_sex_race_both_permute = False
    # is_random_weight = False
    # for randseed in range(num_random_seed): 
    #     onnx_file_path_list, train_stats_list = tell_me_model(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config)
        
    # both-sex-race-permute only model
    # is_race_permute = False 
    # is_sex_permute =  False
    # is_sex_race_both_permute = True
    # is_random_weight = False
    # for randseed in range(num_random_seed): 
    #     onnx_file_path_list, train_stats_list = tell_me_model(randseed, is_race_permute, is_sex_permute, is_sex_race_both_permute, is_random_weight, model_config)
    
df_model_summary = pd.DataFrame.from_records(model_summary)
df_model_summary
# Out:
#         strategy  random_seed model_size  \
# 0       original            0      small
# 1       original            1      small
# 2       original            2      small
# 3       original            3      small
# 4       original            4      small
# 5   race-permute            0      small
# 6   race-permute            1      small
# 7   race-permute            2      small
# 8   race-permute            3      small
# 9   race-permute            4      small
# 10   Rmv-SymDiff            0      small
# 11   Rmv-SymDiff            1      small
# 12   Rmv-SymDiff            2      small
# 13   Rmv-SymDiff            3      small
# 14   Rmv-SymDiff            4      small
# 15   Aug-SymDiff            0      small
# 16   Aug-SymDiff            1      small
# 17   Aug-SymDiff            2      small
# 18   Aug-SymDiff            3      small
# 19   Aug-SymDiff            4      small
# 20      original            0     medium
# 21      original            1     medium
# 22      original            2     medium
# 23      original            3     medium
# 24      original            4     medium
# 25  race-permute            0     medium
# 26  race-permute            1     medium
# 27  race-permute            2     medium
# 28  race-permute            3     medium
# 29  race-permute            4     medium
# 30   Rmv-SymDiff            0     medium
# 31   Rmv-SymDiff            1     medium
# 32   Rmv-SymDiff            2     medium
# 33   Rmv-SymDiff            3     medium
# 34   Rmv-SymDiff            4     medium
# 35   Aug-SymDiff            0     medium
# 36   Aug-SymDiff            1     medium
# 37   Aug-SymDiff            2     medium
# 38   Aug-SymDiff            3     medium
# 39   Aug-SymDiff            4     medium
#
#                                             onnx_list  \
# 0   [NN-verification/results/compas-model_config-s...
# 1   [NN-verification/results/compas-model_config-s...
# 2   [NN-verification/results/compas-model_config-s...
# 3   [NN-verification/results/compas-model_config-s...
# 4   [NN-verification/results/compas-model_config-s...
# 5   [NN-verification/results/compas-model_config-s...
# 6   [NN-verification/results/compas-model_config-s...
# 7   [NN-verification/results/compas-model_config-s...
# 8   [NN-verification/results/compas-model_config-s...
# 9   [NN-verification/results/compas-model_config-s...
# 10  [NN-verification/results/compas-model_config-s...
# 11  [NN-verification/results/compas-model_config-s...
# 12  [NN-verification/results/compas-model_config-s...
# 13  [NN-verification/results/compas-model_config-s...
# 14  [NN-verification/results/compas-model_config-s...
# 15  [NN-verification/results/compas-model_config-s...
# 16  [NN-verification/results/compas-model_config-s...
# 17  [NN-verification/results/compas-model_config-s...
# 18  [NN-verification/results/compas-model_config-s...
# 19  [NN-verification/results/compas-model_config-s...
# 20  [NN-verification/results/compas-model_config-m...
# 21  [NN-verification/results/compas-model_config-m...
# 22  [NN-verification/results/compas-model_config-m...
# 23  [NN-verification/results/compas-model_config-m...
# 24  [NN-verification/results/compas-model_config-m...
# 25  [NN-verification/results/compas-model_config-m...
# 26  [NN-verification/results/compas-model_config-m...
# 27  [NN-verification/results/compas-model_config-m...
# 28  [NN-verification/results/compas-model_config-m...
# 29  [NN-verification/results/compas-model_config-m...
# 30  [NN-verification/results/compas-model_config-m...
# 31  [NN-verification/results/compas-model_config-m...
# 32  [NN-verification/results/compas-model_config-m...
# 33  [NN-verification/results/compas-model_config-m...
# 34  [NN-verification/results/compas-model_config-m...
# 35  [NN-verification/results/compas-model_config-m...
# 36  [NN-verification/results/compas-model_config-m...
# 37  [NN-verification/results/compas-model_config-m...
# 38  [NN-verification/results/compas-model_config-m...
# 39  [NN-verification/results/compas-model_config-m...
#
#                                           model_stats
# 0   [{'train': {'loss_history': [0.661391854286193...
# 1   [{'train': {'loss_history': [0.615472614765167...
# 2   [{'train': {'loss_history': [0.625683665275573...
# 3   [{'train': {'loss_history': [0.634667515754699...
# 4   [{'train': {'loss_history': [0.654579341411590...
# 5   [{'train': {'loss_history': [0.665444970130920...
# 6   [{'train': {'loss_history': [0.645331025123596...
# 7   [{'train': {'loss_history': [0.639143228530883...
# 8   [{'train': {'loss_history': [0.650162339210510...
# 9   [{'train': {'loss_history': [0.663184702396392...
# 10  [{'train': {'loss_history': [0.661391854286193...
# 11  [{'train': {'loss_history': [0.615472614765167...
# 12  [{'train': {'loss_history': [0.625683665275573...
# 13  [{'train': {'loss_history': [0.634667515754699...
# 14  [{'train': {'loss_history': [0.654579341411590...
# 15  [{'train': {'loss_history': [0.661391854286193...
# 16  [{'train': {'loss_history': [0.615472614765167...
# 17  [{'train': {'loss_history': [0.625683665275573...
# 18  [{'train': {'loss_history': [0.634667515754699...
# 19  [{'train': {'loss_history': [0.654579341411590...
# 20  [{'train': {'loss_history': [0.657690763473510...
# 21  [{'train': {'loss_history': [0.650352716445922...
# 22  [{'train': {'loss_history': [0.639057517051696...
# 23  [{'train': {'loss_history': [0.646508753299713...
# 24  [{'train': {'loss_history': [0.662161707878112...
# 25  [{'train': {'loss_history': [0.673280298709869...
# 26  [{'train': {'loss_history': [0.670527279376983...
# 27  [{'train': {'loss_history': [0.652496218681335...
# 28  [{'train': {'loss_history': [0.670808196067810...
# 29  [{'train': {'loss_history': [0.668584167957305...
# 30  [{'train': {'loss_history': [0.657690763473510...
# 31  [{'train': {'loss_history': [0.650352716445922...
# 32  [{'train': {'loss_history': [0.639057517051696...
# 33  [{'train': {'loss_history': [0.646508753299713...
# 34  [{'train': {'loss_history': [0.662161707878112...
# 35  [{'train': {'loss_history': [0.657690763473510...
# 36  [{'train': {'loss_history': [0.650352716445922...
# 37  [{'train': {'loss_history': [0.639057517051696...
# 38  [{'train': {'loss_history': [0.646508753299713...
# 39  [{'train': {'loss_history': [0.662161707878112...

# %% [markdown]
# The features:
# ```
# age             :       normalized to [0,1]
# np_prior         :       normalized to [0,1]
# np_race  :       1 means African-American, 0 means Caucasian
# np_sex         : 1.0 means male, 0.0 means female,
#
# ```

# %%
import copy
models = []
for model in model_summary:
    network_label_template = {
        'strategy': model['strategy'],
        'random_seed': model['random_seed'],
        'model_size': model['model_size'],
    }
    for iteration, (stats, onnx_filename) in enumerate(zip(model['model_stats'], model['onnx_list'])):
        network_label = copy.copy(network_label_template)
        network_label['iteration'] = iteration
        network_label = json.dumps(network_label)
        auc = stats['test']['auc_history'][0]
        models.append((network_label, onnx_filename, auc))


config = {
    'train_data_path': cache_file_path,
    'class_1': {
        'indices': [2],
        'values': [0],
        'label': 'White Person',
        'box': [
            [0.0, 1.0], # age
            [0.0, 1.0], # prior
            [1.0, 1.0], # race
            [0.0, 1.0], # sex
        ]
    },
    'class_2': {
        'indices': [2],
        'values': [1],
        'label': 'Black Person',
        'box': [
            [0.0, 1.0], # age
            [0.0, 1.0], # education
            [1.0, 1.0], # race
            [0.0, 1.0], # sex

        ]
    },
    'discrete_indices': [2, 3],
    'continuous_indices': [0, 1],
    'one_hot_indices': [],
    'fixed_indices': [2],
    'models': models
}

with open('configs/config-compas.json', 'w') as handle:
    json.dump(config, handle)

# %% [markdown]
# # Pick an index to plot train/val/testing curve

# %%
picked_index = 37# the second row from above table

_df_model = df_model_summary.iloc[picked_index]
model_files = _df_model['onnx_list']
train_stats = _df_model['model_stats']
print (model_files) # may have one, or more than one (k-iter for augmented based on SD)
print(train_stats) # may have one, or more than one (k-iter for augmented based on SD)

_df = pd.DataFrame.from_records(train_stats)
_df['test_auc'] = [_['auc_history'][0] for _ in _df['test']]
display_df = None
if 'num_train' in _df.columns:
    display_df = _df[['num_train','test_auc']]
else:
    display_df = _df[['test_auc']]
display_df
# Out:
# ['/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-0.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-1.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-2.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-3.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-4.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-5.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-6.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-7.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-8.onnx', '/Users/xingzhiguo/Documents/git_project/NN-verification/results/adult-v2-model_config-medium-max_epoch=10-train_bs=32-random_seed=2-is_random_weight-False-race_permute=False-sex_permute=False-both_sex_race_permute=False-is_fair_rmv_sym_diff=False-is_fair_copy_sym_diff=True-is_fair_iter_copy_sym_diff=False/model-iter-9.onnx']
# [{'train': {'loss_history': [0.4708273410797119, 0.429693341255188, 0.4271029531955719, 0.42622649669647217, 0.425699383020401]}, 'num_train': 30121, 'dev': {'loss_history': [0.7737756371498108, 0.4338764548301697, 0.43137919902801514, 0.4312790632247925, 0.4300766885280609], 'auc_history': [0.47065694537590563, 0.8217293937775941, 0.8232580451035688, 0.8235447621666139, 0.8244728899839413]}, 'test': {'loss_history': [0.4103349447250366], 'auc_history': [0.8351015648826384]}}, {'train': {'loss_history': [0.47744059562683105, 0.446889191865921, 0.4408891797065735]}, 'num_train': 31572, 'dev': {'loss_history': [0.7585042119026184, 0.5480736494064331, 0.45191603899002075], 'auc_history': [0.4004784820426508, 0.7635690590642212, 0.8121439296871025]}, 'test': {'loss_history': [0.4604094326496124], 'auc_history': [0.8218584491218129]}}, {'train': {'loss_history': [0.4861653745174408, 0.45879873633384705, 0.45223376154899597]}, 'num_train': 34047, 'dev': {'loss_history': [0.6722725629806519, 0.4876101016998291, 0.46113234758377075], 'auc_history': [0.41223774249744355, 0.7613123489355518, 0.795351044219746]}, 'test': {'loss_history': [0.44742700457572937], 'auc_history': [0.7996995617347674]}}, {'train': {'loss_history': [0.5052184462547302, 0.47250425815582275, 0.4622255563735962, 0.46078792214393616, 0.4589850902557373]}, 'num_train': 35039, 'dev': {'loss_history': [0.7834863662719727, 0.5221699476242065, 0.5142239332199097, 0.45264914631843567, 0.4498229920864105], 'auc_history': [0.37544732292341526, 0.7556722508770504, 0.8139492977900381, 0.8040315457125735, 0.8054301300265045]}, 'test': {'loss_history': [0.4324551820755005], 'auc_history': [0.8161339861786919]}}, {'train': {'loss_history': [0.49183425307273865, 0.4722605347633362, 0.46828219294548035, 0.4668166935443878]}, 'num_train': 36160, 'dev': {'loss_history': [0.6605321168899536, 0.5633265972137451, 0.5361410975456238, 0.46512576937675476], 'auc_history': [0.4093182285974257, 0.7773154649740612, 0.7894252417853979, 0.8030998101971019]}, 'test': {'loss_history': [0.4816244840621948], 'auc_history': [0.8168414483754132]}}, {'train': {'loss_history': [0.5116024613380432, 0.4873790442943573]}, 'num_train': 39757, 'dev': {'loss_history': [0.7789450287818909, 0.4624674618244171], 'auc_history': [0.6454113117666405, 0.8126347032206238]}, 'test': {'loss_history': [0.44856223464012146], 'auc_history': [0.8194938935322549]}}, {'train': {'loss_history': [0.5385895371437073, 0.512327253818512, 0.5069579482078552, 0.5041782259941101, 0.5024338960647583]}, 'num_train': 45439, 'dev': {'loss_history': [0.7896711230278015, 0.5765519142150879, 0.46328791975975037, 0.4564517140388489, 0.44739899039268494], 'auc_history': [0.4357665168649128, 0.7641230622546924, 0.8010560808448444, 0.8044105438965722, 0.8109375660620165]}, 'test': {'loss_history': [0.43103525042533875], 'auc_history': [0.8258993385714364]}}, {'train': {'loss_history': [0.5471785068511963, 0.525288462638855]}, 'num_train': 49674, 'dev': {'loss_history': [0.7237741351127625, 0.5730036497116089], 'auc_history': [0.5794413232581084, 0.8041930060277673]}, 'test': {'loss_history': [0.6094327569007874], 'auc_history': [0.7997483477330295]}}, {'train': {'loss_history': [0.5479435324668884, 0.5250317454338074, 0.5187489986419678, 0.5156980752944946, 0.5133398175239563, 0.5113369226455688, 0.5099947452545166, 0.5084192752838135]}, 'num_train': 51147, 'dev': {'loss_history': [0.671393871307373, 0.48733270168304443, 0.47492119669914246, 0.4679718315601349, 0.4612567722797394, 0.4404660761356354, 0.43445587158203125, 0.43139034509658813], 'auc_history': [0.4423060710344372, 0.8062512294655518, 0.815060468818475, 0.8184238561761387, 0.8215623003898592, 0.8258057762158766, 0.8276970328518258, 0.8282961006226254]}, 'test': {'loss_history': [0.4137886166572571], 'auc_history': [0.8354044554921686]}}, {'train': {'loss_history': [0.5546712279319763]}, 'num_train': 53853, 'dev': {'loss_history': [0.6927222609519958], 'auc_history': [0.39293630 ...
#    num_train  test_auc
# 0      30121  0.835102
# 1      31572  0.821858
# 2      34047  0.799700
# 3      35039  0.816134
# 4      36160  0.816841
# 5      39757  0.819494
# 6      45439  0.825899
# 7      49674  0.799748
# 8      51147  0.835404
# 9      53853  0.541039
